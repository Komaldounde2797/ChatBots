# %%
pip install chatterbot

# %%
pip install chatterbot_corpus

# %%
#creating a new chatbot
chatbot = ChatBot(name='ThalaBot',read_only=True,logic_adapters=['chatterbot.logic.BestMatch'])
trainer = ListTrainer(chatbot)



trainer.train([ 'hi','hello','hey','what\'s up?',
               "hey,What\'s your name?","I\'m ThalaBot",
               'how are you?','I\'m good, thank you','how are you?','always cool','glad to hear that','thank you',
               'can you help me to find course','sure,I would love',
               'may i know which courses are availabel?','machine learning, data science, scientific python and ISS coaching program',
               'how i will get information about this courses?','By visiting our website and in training section you will get our courses as well as information about it',
               'fee of machine learning course', 'rs.20000',
               'fee of data science course',  'rs. 30000',
               'fee of scientific python course', 'rs. 5000',
               'fee of ISS coaching program','rs.25000',
               'what company provides?','Thalamus infoTech provides Training to the aspiring data scientist  and provides consulting solutions to grow the businesses with data products',
               'what are the training programs','Machine learning. data science, scientific python and ISS coaching program',
               'consulting solutions of company','Thalamus InfoTech focus on data driven decision making with the help of statistical analysis, Visualization, predictive modeling, ML and DL.Our statistical expertise will help you in analysing your research data and will produce final analysis with key findings.',
               'program structure of scientific python course','20+ Hrs Virtual Classes, three Case Studies,one Minor Project',
               'program structure of data science course','4 Months Program, 120+ Hrs Virtual Classes, 12+ Case Studies, 5+ Webinars by Industry Experts, 1 Major Project',
               'program structure of machine learning course','3 Months Program, 100+ Hrs Virtual Classes, 10+ Case Studies, 5+ Webinars by Industry Experts, 1 Major Project',
               'program struture of ISS coaching course','Virtual Training Program, 6 Month Tenure,250+ Hrs Training',
               'contact no',' You can contact on 8600373650',
               'mail id','suresh.parit@thalamuslabs.ai',
               'youtube channel link','https://youtube.com/channel/UC6uiifjowmvJEm6-9JYwrEA',
               'benefits of machine leaning course','Learn Statistics and ML Concepts from Academic Experts, Real-world case studies to build industry context,Hands-on projects to enhance coding skills, Major Project to consolidate your learning',
               'benefits of data science course','Learn Statistics , Machine Learning and Deep Learning Concepts from Academic Experts, Real-world case studies to build industry context, Hands-on projects to enhance coding skills,Major Project to consolidate Your Learning',
               'benefits of scientific python course','Learn OPP Concepts of Python, Enhance coding skills through Small Challenges, Use of Python for Computing and Visualization,Minor Project to consolidate Your Learning',
               'benefits of ISS coaching program','Reinforce Concepts through Virtual Interactive Class, Weekly and Topic wise Tests,One-on-one guidance,Comprehensive monthly progress,Work on topics that need extra attention, Conceptual Understanding through MCQs,Practice Problems for STATISTICS I and II,Current affairs analysis updates, Discussions and updates based on News, Magazines and Reports,Extensive interview guidance from Experts and ISS Officers',
               ])
trainer.train(['what is data science','Data science is the field of study that combines domain expertise, programming skills, and knowledge of mathematics and statistics to extract meaningful insights from data. ... In turn, these systems generate insights which analysts and business users can translate into tangible business value.'])

trainer.train(['what is machine learning','Machine learning is an application of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning focuses on the development of computer programs that can access data and use it to learn for themselves.'])
# Out:
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%

# %%
while True:
  request=input('You: ')
  response=chatbot.get_response(request)
  print('Bot:',response)
# Out:
# You: hi
# Bot: hello
# You: how are you
# Bot: I'm good, thank you
# You: what is your name
# Bot: I'm ThalaBot
# You: can you help me to find course
# Bot: sure,I would love
# You: what company provides
# Bot: Thalamus infoTech provides Training to the students as well as proessionals and provides consulting solutions to grow the business with data productsgood bye
# You: what is data science
# Bot: 4 Months Program, 120+ Hrs Virtual Classes, 12+ Case Studies, 5+ Webinars by Industry Experts, 1 Major Project
# You: what is machine learning
# Bot: Machine learning is an application of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning focuses on the development of computer programs that can access data and use it to learn for themselves.
# You: fee of data science course
# Bot: rs. 30000
# You: fee of scientific python course
# Bot: rs. 5000
# ...
